# %% [markdown]
# ## ALEXNET ARCHITECTURE

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow
import tensorflow as tf
print(tf.__version__)

import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU

from IPython.display import SVG
from keras.utils import model_to_dot

from time import time
import numpy as np

from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From F:\SOFTWARE\Anaconda\envs\saravanan\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,validation_split = 0.2)
train_data=train.flow_from_directory(directory = 'dataset/train',target_size=(224,224),
                                     batch_size=32,class_mode='categorical')
# Out:
# Found 2000 images belonging to 16 classes.

# %%
test=ImageDataGenerator(rescale=1./255)
test_data=test.flow_from_directory(directory = 'dataset/test',target_size=(224,224),
                                   batch_size=32,class_mode='categorical')
# Out:
# Found 2000 images belonging to 16 classes.

# %%
def alexnet(input_shape, n_classes):
  input = Input(input_shape)
  
  # actually batch normalization didn't exist back then
  # they used LRN (Local Response Normalization) for regularization
  x = Conv2D(96, 11, strides=4, padding='same', activation='relu')(input)
  x = BatchNormalization()(x)
  x = MaxPool2D(3, strides=2)(x)
  
  x = Conv2D(256, 5, padding='same', activation='relu')(x)
  x = BatchNormalization()(x)
  x = MaxPool2D(3, strides=2)(x)
  
  x = Conv2D(384, 3, strides=1, padding='same', activation='relu')(x)
  
  x = Conv2D(384, 3, strides=1, padding='same', activation='relu')(x)
  
  x = Conv2D(256, 3, strides=1, padding='same', activation='relu')(x)
  x = BatchNormalization()(x)
  x = MaxPool2D(3, strides=2)(x)
  
  x = Flatten()(x)
  x = Dense(4096, activation='relu')(x)
  x = Dense(4096, activation='relu')(x)
  
  output = Dense(n_classes, activation='softmax')(x)
  
  model = Model(input, output)
  model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy',tensorflow.keras.metrics.Precision()])
  return model

input_shape = 224, 224, 3
n_classes = 16

K.clear_session()
model = alexnet(input_shape, n_classes)
model.summary()
# Out:
# WARNING:tensorflow:From F:\SOFTWARE\Anaconda\envs\saravanan\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From F:\SOFTWARE\Anaconda\envs\saravanan\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From F:\SOFTWARE\Anaconda\envs\saravanan\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv2d (Conv2D)             (None, 56, 56, 96)        34944
#
#  batch_normalization (Batch  (None, 56, 56, 96)        384
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 27, 27, 96)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 27, 27, 256)       614656
#
#  batch_normalization_1 (Bat  (None, 27, 27, 256)       1024
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 13, 13, 256)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 384)       885120
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 256)       884992
#
#  batch_normalization_2 (Bat  (None, 13, 13, 256)       1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 4096)              37752832
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 16)                65552
#
# =================================================================
# Total params: 58349328 (222.59 MB)
# Trainable params: 58348112 (222.58 MB)
# Non-trainable params: 1216 (4.75 KB)
# _________________________________________________________________

# %%
model_path = "ALEXNET.h5"

from keras.callbacks import ModelCheckpoint

M = ModelCheckpoint(model_path, monitor='accuracy', verbose=1, save_best_only=True)

# %%
epochs = 100
batch_size = 512

# %%
#### Fitting the model
history = model.fit(
           train_data, steps_per_epoch=train_data.samples // batch_size, 
           epochs=epochs, 
           validation_data=test_data,validation_steps=test_data.samples // batch_size,
           callbacks=[M])
# Out:
# Epoch 1/100
# WARNING:tensorflow:From F:\SOFTWARE\Anaconda\envs\saravanan\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From F:\SOFTWARE\Anaconda\envs\saravanan\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - ETA: 0s - loss: 40.3442 - accuracy: 0.0833 - precision: 0.0735
# Epoch 1: accuracy improved from -inf to 0.08333, saving model to ALEXNET.h5
# 3/3 [==============================] - 16s 5s/step - loss: 40.3442 - accuracy: 0.0833 - precision: 0.0735 - val_loss: 41.1999 - val_accuracy: 0.0312 - val_precision: 0.0312
# Epoch 2/100
# 3/3 [==============================] - ETA: 0s - loss: 42.8471 - accuracy: 0.1354 - precision: 0.1282
# Epoch 2: accuracy improved from 0.08333 to 0.13542, saving model to ALEXNET.h5
# 3/3 [==============================] - 25s 11s/step - loss: 42.8471 - accuracy: 0.1354 - precision: 0.1282 - val_loss: 19.8502 - val_accuracy: 0.0625 - val_precision: 0.0625
# Epoch 3/100
# 3/3 [==============================] - ETA: 0s - loss: 8.1618 - accuracy: 0.1667 - precision: 0.1636
# Epoch 3: accuracy improved from 0.13542 to 0.16667, saving model to ALEXNET.h5
# 3/3 [==============================] - 15s 6s/step - loss: 8.1618 - accuracy: 0.1667 - precision: 0.1636 - val_loss: 9.1016 - val_accuracy: 0.0312 - val_precision: 0.1333
# Epoch 4/100
# 3/3 [==============================] - ETA: 0s - loss: 2.8041 - accuracy: 0.1875 - precision: 0.2308
# Epoch 4: accuracy improved from 0.16667 to 0.18750, saving model to ALEXNET.h5
# 3/3 [==============================] - 18s 7s/step - loss: 2.8041 - accuracy: 0.1875 - precision: 0.2308 - val_loss: 11.0319 - val_accuracy: 0.0208 - val_precision: 0.0211
# Epoch 5/100
# 3/3 [==============================] - ETA: 0s - loss: 2.6235 - accuracy: 0.2188 - precision: 0.5000
# Epoch 5: accuracy improved from 0.18750 to 0.21875, saving model to ALEXNET.h5
# 3/3 [==============================] - 25s 11s/step - loss: 2.6235 - accuracy: 0.2188 - precision: 0.5000 - val_loss: 5.5726 - val_accuracy: 0.0417 - val_precision: 0.0000e+00
# Epoch 6/100
# 3/3 [==============================] - ETA: 0s - loss: 2.1467 - accuracy: 0.2188 - precision: 0.6667
# Epoch 6: accuracy did not improve from 0.21875
# 3/3 [==============================] - 13s 4s/step - loss: 2.1467 - accuracy: 0.2188 - precision: 0.6667 - val_loss: 4.3780 - val_accuracy: 0.0417 - val_precision: 0.0000e+00
# Epoch 7/100
# 3/3 [==============================] - ETA: 0s - loss: 2.2832 - accuracy: 0.2396 - precision: 0.4118
# Epoch 7: accuracy improved from 0.21875 to 0.23958, saving model to ALEXNET.h5
# 3/3 [==============================] - 14s 5s/step - loss: 2.2832 - accuracy: 0.2396 - precision: 0.4118 - val_loss: 6.0859 - val_accuracy: 0.0625 - val_precision: 0.1220
# Epoch 8/100
# 3/3 [==============================] - ETA: 0s - loss: 1.7693 - accuracy: 0.3750 - precision: 0.4828
# Epoch 8: accuracy improved from 0.23958 to 0.37500, saving model to ALEXNET.h5
# 3/3 [==============================] - 14s 5s/step - loss: 1.7693 - accuracy: 0.3750 - precision: 0.4828 - val_loss: 5.7503 - val_accuracy: 0.0417 - val_precision: 0.0556
# Epoch 9/100
# 3/3 [==============================] - ETA: 0s - loss: 1.7867 - accuracy: 0.4271 - precision: 0.5429
# Epoch 9: accuracy improved from 0.37500 to 0.42708, saving model to ALEXNET.h5
# 3/3 [==============================] - 31s 14s/step - loss: 1.7867 - accuracy: 0.4271 - precision: 0.5429 - val_loss: 5.7727 - val_accuracy: 0.0417 - val_precision: 0.0519
# Epoch 10/100
# 3/3 [==============================] - ETA: 0s - loss: 1.8262 - accuracy: 0.3646 - precision: 0.5217
# Epoch 10: accuracy did not improve from 0.42708
# 3/3 [==============================] - 10s 4s/step - loss: 1.8262 - accuracy: 0.3646 - precision: 0.5217 - val_loss: 5.7297 - val_accuracy: 0.0938 - val_precision: 0.1429
# Epoch 11/100
# 3/3 [==============================] - ETA: 0s - loss: 1.8852 - accuracy: 0.3646 - precision: 0.5588
# Epoch 11: accuracy did not improve from 0.42708
# 3/3 [==============================] - 11s 4s/step - loss: 1.8852 - accuracy: 0.3646 - precision: 0.5588 - val_loss: 6.1632 - val_accuracy: 0.0625 - val_precision: 0.0625
# Epoch 12/100
# 3/3 [==============================] - ETA: 0s - loss: 1.6577 - accuracy: 0.4375 - precision: 0.6410
# Epoch 12: accuracy improved from 0.42708 to 0.43750, saving model to ALEXNET.h5
# 3/3 [==============================] - 13s 5s/step - loss: 1.6577 - accuracy: 0.4375 - precision: 0.6410 - val_loss: 6.8694 - val_accuracy: 0.0729 - val_precision: 0.0814
# Epoch 13/100
# 3/3 [==============================] - ETA: 0s - loss: 1.6130 - accuracy: 0.3750 - precision: 0.5833
# Epoch 13: accuracy did not improve from 0.43750
# 3/3 [==============================] - 12s 4s/step - loss: 1.6130 - accuracy: 0.3750 - precision: 0.5833 - val_loss: 6.6542 - val_accuracy: 0.0833 - val_precision: 0.1000
# Epoch 14/100
# 3/3 [==============================] - ETA: 0s - loss: 1.4779 - accuracy: 0.4062 - precision: 0.6053
# Epoch 14: accuracy did not improve from 0.43750
# 3/3 [==============================] - 12s 4s/step - loss: 1.4779 - accuracy: 0.4062 - precision: 0.6053 - val_loss: 4.5572 - val_accuracy: 0.1354 - val_precision: 0.2273
# Epoch 15/100
# 3/3 [==============================] - ETA: 0s - loss: 1.5078 - accuracy: 0.4583 - precision: 0.5476
# Epoch 15: accuracy improved from 0.43750 to 0.45833, saving model to ALEXNET.h5
# 3/3 [==============================] - 14s 5s/step - loss: 1.5078 - accuracy: 0.4583 - precision: 0.5476 - val_loss: 4.7114 - val_accuracy: 0.0417 - val_precision: 0.0500
# Epoch 16/100
# 3/3 [==============================] - ETA: 0s - loss: 1.6773 - accuracy: 0.3646 - precision: 0.4510
# Epoch 16: accuracy did not improve from 0.45833
# 3/3 [==============================] - 12s 5s/step - loss: 1.6773 - accuracy: 0.3646 - precision: 0.4510 - val_loss: 3.6461 - val_accuracy: 0.0312 - val_precision: 0.0000e+00
# Epoch 17/100
# 3/3 [==============================] - ETA: 0s - loss: 1.4437 - accuracy: 0.4375 - precision: 0.6042
# Epoch 17: accuracy did not improve from 0.45833
# 3/3 [==============================] - 14s 5s/step - loss: 1.4437 - accuracy: 0.4375 - precision: 0.6042 - val_loss: 3.4495 - val_accuracy: 0.0521 - val_precision: 0.0000e+00
# Epoch 18/100
# 3/3 [==============================] - ETA: 0s - loss: 1.2546 - accuracy: 0.5312 - precision: 0.6038
# Epoch 18: accuracy improved from 0.45833 to 0.53125, saving model to ALEXNET.h5
# 3/3 [==============================] - 14s 5s/step - loss: 1.2546 - accuracy: 0.5312 - precision: 0.6038 - val_loss: 3.2964 - val_accuracy: 0.1354 - val_precision: 0.4000
# Epoch 19/100
# 3/3 [==============================] - ETA: 0s - loss: 1.3940 - accuracy: 0.5000 - precision: 0.6786
# Epoch 19: accuracy did not improve from 0.53125
# 3/3 [==============================] - 11s 4s/step - loss: 1.3940 - accuracy: 0.5000 - precision: 0.6786 - val_loss: 4.2859 - val_accuracy: 0.1250 - val_precision: 0.1852
# Epoch 20/100
# 3/3 [==============================] - ETA: 0s - loss: 1.7307 - accuracy: 0.4792 - precision: 0.5846
# Epoch 20: accuracy did not improve from 0.53125
# 3/3 [==============================] - 12s 4s/step - loss: 1.7307 - accuracy: 0.4792 - precision: 0.5846 - val_loss: 3.2279 - val_accuracy: 0.1771 - val_precision: 0.1333
# Epoch 21/100
# 3/3 [==============================] - ETA: 0s - loss: 1.3151 - accuracy: 0.5729 - precision: 0.7321
# Epoch 21: accuracy improved from 0.53125 to 0.57292, saving model to ALEXNET.h5
# 3/3 [==============================] - 15s 6s/step - loss: 1.3151 - accuracy: 0.5729 - precision: 0.7321 - val_loss: 2.7790 - val_accuracy: 0.1667 - val_precision: 0.0000e+00
# Epoch 22/100
# 3/3 [==============================] - ETA: 0s - loss: 1.3006 - accuracy: 0.5833 - precision: 0.7778
# Epoch 22: accuracy improved from 0.57292 to 0.58333, saving model to ALEXNET.h5
# 3/3 [==============================] - 16s 6s/step - loss: 1.3006 - accuracy: 0.5833 - precision: 0.7778 - val_loss: 2.8444 - val_accuracy: 0.1458 - val_precision: 1.0000
# Epoch 23/100
# 3/3 [==============================] - ETA: 0s - loss: 1.1809 - accuracy: 0.5833 - precision: 0.7544
# Epoch 23: accuracy did not improve from 0.58333
# 3/3 [==============================] - 13s 5s/step - loss: 1.1809 - accuracy: 0.5833 - precision: 0.7544 - val_loss: 2.4914 - val_accuracy: 0.1562 - val_precision: 0.4211
# Epoch 24/100
# 3/3 [==============================] - ETA: 0s - loss: 1.1307 - accuracy: 0.5375 - precision: 0.7333
# Epoch 24: accuracy did not improve from 0.58333
# 3/3 [==============================] - 12s 5s/step - loss: 1.1307 - accuracy: 0.5375 - precision: 0.7333 - val_loss: 2.9130 - val_accuracy: 0.2083 - val_precision: 0.4737
# Epoch 25/100
# 3/3 [==============================] - ETA: 0s - loss: 1.3639 - accuracy: 0.4896 - precision: 0.6102
# Epoch 25: accuracy did not improve from 0.58333
# 3/3 [==============================] - 14s 5s/step - loss: 1.3639 - accuracy: 0.4896 - precision: 0.6102 - val_loss: 2.8150 - val_accuracy: 0.2083 - val_precision: 0.3125
# Epoch 26/100
# 3/3 [==============================] - ETA: 0s - loss: 1.1105 - accuracy: 0.6458 - precision: 0.7353
# Epoch 26: accuracy improved from 0.58333 to 0.64583, saving model to ALEXNET.h5
# 3/3 [==============================] - 16s 6s/step - loss: 1.1105 - accuracy: 0.6458 - precision: 0.7353 - val_loss: 2.9059 - val_accuracy: 0.1042 - val_precision: 0.1500
# Epoch 27/100
# 3/3 [==============================] - ETA: 0s - loss: 1.2273 - accuracy: 0.5729 - precision: 0.6462
# Epoch 27: accuracy did not improve from 0.64583
# 3/3 [==============================] - 13s 5s/step - loss: 1.2273 - accuracy: 0.5729 - precision: 0.6462 - val_loss: 2.6873 - val_accuracy: 0.2292 - val_precision: 0.5833
# Epoch 28/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9682 - accuracy: 0.6667 - precision: 0.8167
# Epoch 28: accuracy improved from 0.64583 to 0.66667, saving model to ALEXNET.h5
# 3/3 [==============================] - 16s 6s/step - loss: 0.9682 - accuracy: 0.6667 - precision: 0.8167 - val_loss: 2.6386 - val_accuracy: 0.1875 - val_precision: 0.4074
# Epoch 29/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9777 - accuracy: 0.6562 - precision: 0.7812
# Epoch 29: accuracy did not improve from 0.66667
# 3/3 [==============================] - 13s 5s/step - loss: 0.9777 - accuracy: 0.6562 - precision: 0.7812 - val_loss: 3.1843 - val_accuracy: 0.2292 - val_precision: 0.1765
# Epoch 30/100
# 3/3 [==============================] - ETA: 0s - loss: 1.1374 - accuracy: 0.6562 - precision: 0.6944
# Epoch 30: accuracy did not improve from 0.66667
# 3/3 [==============================] - 14s 4s/step - loss: 1.1374 - accuracy: 0.6562 - precision: 0.6944 - val_loss: 3.1664 - val_accuracy: 0.1771 - val_precision: 0.2500
# Epoch 31/100
# 3/3 [==============================] - ETA: 0s - loss: 1.1721 - accuracy: 0.5938 - precision: 0.6957
# Epoch 31: accuracy did not improve from 0.66667
# 3/3 [==============================] - 14s 5s/step - loss: 1.1721 - accuracy: 0.5938 - precision: 0.6957 - val_loss: 3.0605 - val_accuracy: 0.2396 - val_precision: 0.3913
# Epoch 32/100
# 3/3 [==============================] - ETA: 0s - loss: 1.2219 - accuracy: 0.6042 - precision: 0.6825
# Epoch 32: accuracy did not improve from 0.66667
# 3/3 [==============================] - 14s 5s/step - loss: 1.2219 - accuracy: 0.6042 - precision: 0.6825 - val_loss: 2.4156 - val_accuracy: 0.2917 - val_precision: 0.4667
# Epoch 33/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9000 - accuracy: 0.6458 - precision: 0.7500
# Epoch 33: accuracy did not improve from 0.66667
# 3/3 [==============================] - 14s 5s/step - loss: 0.9000 - accuracy: 0.6458 - precision: 0.7500 - val_loss: 2.1274 - val_accuracy: 0.2917 - val_precision: 0.5172
# Epoch 34/100
# 3/3 [==============================] - ETA: 0s - loss: 1.0691 - accuracy: 0.6875 - precision: 0.7037
# Epoch 34: accuracy improved from 0.66667 to 0.68750, saving model to ALEXNET.h5
# 3/3 [==============================] - 15s 5s/step - loss: 1.0691 - accuracy: 0.6875 - precision: 0.7037 - val_loss: 1.8975 - val_accuracy: 0.3542 - val_precision: 0.7812
# Epoch 35/100
# 3/3 [==============================] - ETA: 0s - loss: 1.2454 - accuracy: 0.5312 - precision: 0.6866
# Epoch 35: accuracy did not improve from 0.68750
# 3/3 [==============================] - 13s 5s/step - loss: 1.2454 - accuracy: 0.5312 - precision: 0.6866 - val_loss: 2.3750 - val_accuracy: 0.2708 - val_precision: 0.3500
# Epoch 36/100
# 3/3 [==============================] - ETA: 0s - loss: 1.0264 - accuracy: 0.6562 - precision: 0.7714
# Epoch 36: accuracy did not improve from 0.68750
# 3/3 [==============================] - 15s 5s/step - loss: 1.0264 - accuracy: 0.6562 - precision: 0.7714 - val_loss: 2.6875 - val_accuracy: 0.3021 - val_precision: 0.3784
# Epoch 37/100
# 3/3 [==============================] - ETA: 0s - loss: 1.1385 - accuracy: 0.5938 - precision: 0.6857
# Epoch 37: accuracy did not improve from 0.68750
# 3/3 [==============================] - 20s 8s/step - loss: 1.1385 - accuracy: 0.5938 - precision: 0.6857 - val_loss: 1.9321 - val_accuracy: 0.3542 - val_precision: 0.6296
# Epoch 38/100
# 3/3 [==============================] - ETA: 0s - loss: 1.1275 - accuracy: 0.5625 - precision: 0.7188
# Epoch 38: accuracy did not improve from 0.68750
# 3/3 [==============================] - 23s 7s/step - loss: 1.1275 - accuracy: 0.5625 - precision: 0.7188 - val_loss: 2.0345 - val_accuracy: 0.2708 - val_precision: 0.5500
# Epoch 39/100
# 3/3 [==============================] - ETA: 0s - loss: 1.0530 - accuracy: 0.6562 - precision: 0.7568
# Epoch 39: accuracy did not improve from 0.68750
# 3/3 [==============================] - 17s 6s/step - loss: 1.0530 - accuracy: 0.6562 - precision: 0.7568 - val_loss: 1.8434 - val_accuracy: 0.3646 - val_precision: 0.6667
# Epoch 40/100
# 3/3 [==============================] - ETA: 0s - loss: 1.0034 - accuracy: 0.6562 - precision: 0.8000
# Epoch 40: accuracy did not improve from 0.68750
# 3/3 [==============================] - 15s 5s/step - loss: 1.0034 - accuracy: 0.6562 - precision: 0.8000 - val_loss: 1.5504 - val_accuracy: 0.4062 - val_precision: 0.7600
# Epoch 41/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9715 - accuracy: 0.6354 - precision: 0.7656
# Epoch 41: accuracy did not improve from 0.68750
# 3/3 [==============================] - 17s 6s/step - loss: 0.9715 - accuracy: 0.6354 - precision: 0.7656 - val_loss: 1.6477 - val_accuracy: 0.4062 - val_precision: 0.7500
# Epoch 42/100
# 3/3 [==============================] - ETA: 0s - loss: 1.3209 - accuracy: 0.5625 - precision: 0.6389
# Epoch 42: accuracy did not improve from 0.68750
# 3/3 [==============================] - 18s 6s/step - loss: 1.3209 - accuracy: 0.5625 - precision: 0.6389 - val_loss: 1.9334 - val_accuracy: 0.3958 - val_precision: 0.5778
# Epoch 43/100
# 3/3 [==============================] - ETA: 0s - loss: 1.0440 - accuracy: 0.5521 - precision: 0.6410
# Epoch 43: accuracy did not improve from 0.68750
# 3/3 [==============================] - 17s 6s/step - loss: 1.0440 - accuracy: 0.5521 - precision: 0.6410 - val_loss: 2.1572 - val_accuracy: 0.3958 - val_precision: 0.5254
# Epoch 44/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8770 - accuracy: 0.7292 - precision: 0.7647
# Epoch 44: accuracy improved from 0.68750 to 0.72917, saving model to ALEXNET.h5
# 3/3 [==============================] - 18s 7s/step - loss: 0.8770 - accuracy: 0.7292 - precision: 0.7647 - val_loss: 1.8431 - val_accuracy: 0.4062 - val_precision: 0.5000
# Epoch 45/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9953 - accuracy: 0.6562 - precision: 0.7763
# Epoch 45: accuracy did not improve from 0.72917
# 3/3 [==============================] - 15s 6s/step - loss: 0.9953 - accuracy: 0.6562 - precision: 0.7763 - val_loss: 4.7443 - val_accuracy: 0.1771 - val_precision: 0.2031
# Epoch 46/100
# 3/3 [==============================] - ETA: 0s - loss: 1.2288 - accuracy: 0.5625 - precision: 0.6486
# Epoch 46: accuracy did not improve from 0.72917
# 3/3 [==============================] - 18s 6s/step - loss: 1.2288 - accuracy: 0.5625 - precision: 0.6486 - val_loss: 5.4263 - val_accuracy: 0.1771 - val_precision: 0.1918
# Epoch 47/100
# 3/3 [==============================] - ETA: 0s - loss: 1.0371 - accuracy: 0.5833 - precision: 0.6757
# Epoch 47: accuracy did not improve from 0.72917
# 3/3 [==============================] - 18s 6s/step - loss: 1.0371 - accuracy: 0.5833 - precision: 0.6757 - val_loss: 4.3140 - val_accuracy: 0.3333 - val_precision: 0.3288
# Epoch 48/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9420 - accuracy: 0.7188 - precision: 0.7895
# Epoch 48: accuracy did not improve from 0.72917
# 3/3 [==============================] - 17s 5s/step - loss: 0.9420 - accuracy: 0.7188 - precision: 0.7895 - val_loss: 3.4540 - val_accuracy: 0.3750 - val_precision: 0.4746
# Epoch 49/100
# 3/3 [==============================] - ETA: 0s - loss: 1.0400 - accuracy: 0.6667 - precision: 0.7778
# Epoch 49: accuracy did not improve from 0.72917
# 3/3 [==============================] - 15s 5s/step - loss: 1.0400 - accuracy: 0.6667 - precision: 0.7778 - val_loss: 2.9267 - val_accuracy: 0.3854 - val_precision: 0.4694
# Epoch 50/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9095 - accuracy: 0.6979 - precision: 0.7867
# Epoch 50: accuracy did not improve from 0.72917
# 3/3 [==============================] - 15s 5s/step - loss: 0.9095 - accuracy: 0.6979 - precision: 0.7867 - val_loss: 2.3456 - val_accuracy: 0.4271 - val_precision: 0.5455
# Epoch 51/100
# 3/3 [==============================] - ETA: 0s - loss: 1.1304 - accuracy: 0.5938 - precision: 0.7015
# Epoch 51: accuracy did not improve from 0.72917
# 3/3 [==============================] - 18s 6s/step - loss: 1.1304 - accuracy: 0.5938 - precision: 0.7015 - val_loss: 1.4346 - val_accuracy: 0.4896 - val_precision: 0.6491
# Epoch 52/100
# 3/3 [==============================] - ETA: 0s - loss: 1.0794 - accuracy: 0.7125 - precision: 0.7576
# Epoch 52: accuracy did not improve from 0.72917
# 3/3 [==============================] - 14s 5s/step - loss: 1.0794 - accuracy: 0.7125 - precision: 0.7576 - val_loss: 1.9303 - val_accuracy: 0.3333 - val_precision: 0.4500
# Epoch 53/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8038 - accuracy: 0.7188 - precision: 0.7848
# Epoch 53: accuracy did not improve from 0.72917
# 3/3 [==============================] - 14s 5s/step - loss: 0.8038 - accuracy: 0.7188 - precision: 0.7848 - val_loss: 2.2103 - val_accuracy: 0.4375 - val_precision: 0.4776
# Epoch 54/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8584 - accuracy: 0.7292 - precision: 0.7606
# Epoch 54: accuracy did not improve from 0.72917
# 3/3 [==============================] - 14s 5s/step - loss: 0.8584 - accuracy: 0.7292 - precision: 0.7606 - val_loss: 1.4561 - val_accuracy: 0.5417 - val_precision: 0.5972
# Epoch 55/100
# 3/3 [==============================] - ETA: 0s - loss: 1.0331 - accuracy: 0.6458 - precision: 0.7162
# Epoch 55: accuracy did not improve from 0.72917
# 3/3 [==============================] - 16s 6s/step - loss: 1.0331 - accuracy: 0.6458 - precision: 0.7162 - val_loss: 1.3141 - val_accuracy: 0.5625 - val_precision: 0.6379
# Epoch 56/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9877 - accuracy: 0.6458 - precision: 0.7162
# Epoch 56: accuracy did not improve from 0.72917
# 3/3 [==============================] - 18s 6s/step - loss: 0.9877 - accuracy: 0.6458 - precision: 0.7162 - val_loss: 1.4907 - val_accuracy: 0.5312 - val_precision: 0.6029
# Epoch 57/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8194 - accuracy: 0.7500 - precision: 0.8052
# Epoch 57: accuracy improved from 0.72917 to 0.75000, saving model to ALEXNET.h5
# 3/3 [==============================] - 18s 6s/step - loss: 0.8194 - accuracy: 0.7500 - precision: 0.8052 - val_loss: 1.4612 - val_accuracy: 0.4896 - val_precision: 0.5970
# Epoch 58/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8317 - accuracy: 0.6979 - precision: 0.8108
# Epoch 58: accuracy did not improve from 0.75000
# 3/3 [==============================] - 15s 6s/step - loss: 0.8317 - accuracy: 0.6979 - precision: 0.8108 - val_loss: 1.3924 - val_accuracy: 0.5208 - val_precision: 0.7200
# Epoch 59/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8052 - accuracy: 0.7604 - precision: 0.7619
# Epoch 59: accuracy improved from 0.75000 to 0.76042, saving model to ALEXNET.h5
# 3/3 [==============================] - 29s 12s/step - loss: 0.8052 - accuracy: 0.7604 - precision: 0.7619 - val_loss: 1.2828 - val_accuracy: 0.6458 - val_precision: 0.7755
# Epoch 60/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9992 - accuracy: 0.6562 - precision: 0.7308
# Epoch 60: accuracy did not improve from 0.76042
# 3/3 [==============================] - 16s 6s/step - loss: 0.9992 - accuracy: 0.6562 - precision: 0.7308 - val_loss: 1.5559 - val_accuracy: 0.4271 - val_precision: 0.5536
# Epoch 61/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8198 - accuracy: 0.7083 - precision: 0.8082
# Epoch 61: accuracy did not improve from 0.76042
# 3/3 [==============================] - 17s 6s/step - loss: 0.8198 - accuracy: 0.7083 - precision: 0.8082 - val_loss: 2.2335 - val_accuracy: 0.3542 - val_precision: 0.3750
# Epoch 62/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8427 - accuracy: 0.7188 - precision: 0.7500
# Epoch 62: accuracy did not improve from 0.76042
# 3/3 [==============================] - 24s 8s/step - loss: 0.8427 - accuracy: 0.7188 - precision: 0.7500 - val_loss: 3.1643 - val_accuracy: 0.3125 - val_precision: 0.3857
# Epoch 63/100
# 3/3 [==============================] - ETA: 0s - loss: 0.6832 - accuracy: 0.7604 - precision: 0.8421
# Epoch 63: accuracy did not improve from 0.76042
# 3/3 [==============================] - 21s 7s/step - loss: 0.6832 - accuracy: 0.7604 - precision: 0.8421 - val_loss: 2.1400 - val_accuracy: 0.4062 - val_precision: 0.4677
# Epoch 64/100
# 3/3 [==============================] - ETA: 0s - loss: 0.7283 - accuracy: 0.6979 - precision: 0.7531
# Epoch 64: accuracy did not improve from 0.76042
# 3/3 [==============================] - 17s 6s/step - loss: 0.7283 - accuracy: 0.6979 - precision: 0.7531 - val_loss: 1.4018 - val_accuracy: 0.4792 - val_precision: 0.5593
# Epoch 65/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8939 - accuracy: 0.6562 - precision: 0.7500
# Epoch 65: accuracy did not improve from 0.76042
# 3/3 [==============================] - 16s 5s/step - loss: 0.8939 - accuracy: 0.6562 - precision: 0.7500 - val_loss: 1.2565 - val_accuracy: 0.6667 - val_precision: 0.7500
# Epoch 66/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9025 - accuracy: 0.6458 - precision: 0.7662
# Epoch 66: accuracy did not improve from 0.76042
# 3/3 [==============================] - 17s 6s/step - loss: 0.9025 - accuracy: 0.6458 - precision: 0.7662 - val_loss: 1.7402 - val_accuracy: 0.4271 - val_precision: 0.5763
# Epoch 67/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9449 - accuracy: 0.7083 - precision: 0.7778
# Epoch 67: accuracy did not improve from 0.76042
# 3/3 [==============================] - 15s 5s/step - loss: 0.9449 - accuracy: 0.7083 - precision: 0.7778 - val_loss: 1.2993 - val_accuracy: 0.4896 - val_precision: 0.6393
# Epoch 68/100
# 3/3 [==============================] - ETA: 0s - loss: 0.7888 - accuracy: 0.7604 - precision: 0.8400
# Epoch 68: accuracy did not improve from 0.76042
# 3/3 [==============================] - 15s 5s/step - loss: 0.7888 - accuracy: 0.7604 - precision: 0.8400 - val_loss: 1.5852 - val_accuracy: 0.5104 - val_precision: 0.6545
# Epoch 69/100
# 3/3 [==============================] - ETA: 0s - loss: 1.0386 - accuracy: 0.5938 - precision: 0.6410
# Epoch 69: accuracy did not improve from 0.76042
# 3/3 [==============================] - 15s 5s/step - loss: 1.0386 - accuracy: 0.5938 - precision: 0.6410 - val_loss: 1.8693 - val_accuracy: 0.4167 - val_precision: 0.5472
# Epoch 70/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8741 - accuracy: 0.7292 - precision: 0.8267
# Epoch 70: accuracy did not improve from 0.76042
# 3/3 [==============================] - 14s 5s/step - loss: 0.8741 - accuracy: 0.7292 - precision: 0.8267 - val_loss: 1.3745 - val_accuracy: 0.5208 - val_precision: 0.6500
# Epoch 71/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9288 - accuracy: 0.6146 - precision: 0.7333
# Epoch 71: accuracy did not improve from 0.76042
# 3/3 [==============================] - 14s 5s/step - loss: 0.9288 - accuracy: 0.6146 - precision: 0.7333 - val_loss: 1.3629 - val_accuracy: 0.4583 - val_precision: 0.7111
# Epoch 72/100
# 3/3 [==============================] - ETA: 0s - loss: 0.7014 - accuracy: 0.7708 - precision: 0.8481
# Epoch 72: accuracy improved from 0.76042 to 0.77083, saving model to ALEXNET.h5
# 3/3 [==============================] - 16s 6s/step - loss: 0.7014 - accuracy: 0.7708 - precision: 0.8481 - val_loss: 1.2223 - val_accuracy: 0.6042 - val_precision: 0.7692
# Epoch 73/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8956 - accuracy: 0.7188 - precision: 0.7821
# Epoch 73: accuracy did not improve from 0.77083
# 3/3 [==============================] - 13s 5s/step - loss: 0.8956 - accuracy: 0.7188 - precision: 0.7821 - val_loss: 1.5482 - val_accuracy: 0.4688 - val_precision: 0.6032
# Epoch 74/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8500 - accuracy: 0.7188 - precision: 0.7590
# Epoch 74: accuracy did not improve from 0.77083
# 3/3 [==============================] - 14s 5s/step - loss: 0.8500 - accuracy: 0.7188 - precision: 0.7590 - val_loss: 1.3069 - val_accuracy: 0.5417 - val_precision: 0.6351
# Epoch 75/100
# 3/3 [==============================] - ETA: 0s - loss: 1.1094 - accuracy: 0.6146 - precision: 0.6709
# Epoch 75: accuracy did not improve from 0.77083
# 3/3 [==============================] - 14s 5s/step - loss: 1.1094 - accuracy: 0.6146 - precision: 0.6709 - val_loss: 1.3230 - val_accuracy: 0.5521 - val_precision: 0.5750
# Epoch 76/100
# 3/3 [==============================] - ETA: 0s - loss: 0.7384 - accuracy: 0.7083 - precision: 0.7209
# Epoch 76: accuracy did not improve from 0.77083
# 3/3 [==============================] - 13s 4s/step - loss: 0.7384 - accuracy: 0.7083 - precision: 0.7209 - val_loss: 1.5387 - val_accuracy: 0.6250 - val_precision: 0.6957
# Epoch 77/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8679 - accuracy: 0.6875 - precision: 0.7895
# Epoch 77: accuracy did not improve from 0.77083
# 3/3 [==============================] - 11s 4s/step - loss: 0.8679 - accuracy: 0.6875 - precision: 0.7895 - val_loss: 1.3041 - val_accuracy: 0.6146 - val_precision: 0.6944
# Epoch 78/100
# 3/3 [==============================] - ETA: 0s - loss: 0.6960 - accuracy: 0.7500 - precision: 0.8375
# Epoch 78: accuracy did not improve from 0.77083
# 3/3 [==============================] - 10s 4s/step - loss: 0.6960 - accuracy: 0.7500 - precision: 0.8375 - val_loss: 1.3217 - val_accuracy: 0.6146 - val_precision: 0.7015
# Epoch 79/100
# 3/3 [==============================] - ETA: 0s - loss: 0.6973 - accuracy: 0.7812 - precision: 0.8750
# Epoch 79: accuracy improved from 0.77083 to 0.78125, saving model to ALEXNET.h5
# 3/3 [==============================] - 13s 5s/step - loss: 0.6973 - accuracy: 0.7812 - precision: 0.8750 - val_loss: 1.3191 - val_accuracy: 0.6042 - val_precision: 0.6849
# Epoch 80/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8599 - accuracy: 0.6458 - precision: 0.7125
# Epoch 80: accuracy did not improve from 0.78125
# 3/3 [==============================] - 11s 4s/step - loss: 0.8599 - accuracy: 0.6458 - precision: 0.7125 - val_loss: 1.9501 - val_accuracy: 0.6771 - val_precision: 0.7463
# Epoch 81/100
# 3/3 [==============================] - ETA: 0s - loss: 0.7306 - accuracy: 0.7188 - precision: 0.7662
# Epoch 81: accuracy did not improve from 0.78125
# 3/3 [==============================] - 10s 4s/step - loss: 0.7306 - accuracy: 0.7188 - precision: 0.7662 - val_loss: 0.7269 - val_accuracy: 0.7396 - val_precision: 0.8889
# Epoch 82/100
# 3/3 [==============================] - ETA: 0s - loss: 0.7102 - accuracy: 0.7083 - precision: 0.7662
# Epoch 82: accuracy did not improve from 0.78125
# 3/3 [==============================] - 11s 4s/step - loss: 0.7102 - accuracy: 0.7083 - precision: 0.7662 - val_loss: 1.3514 - val_accuracy: 0.5417 - val_precision: 0.6667
# Epoch 83/100
# 3/3 [==============================] - ETA: 0s - loss: 0.6537 - accuracy: 0.7500 - precision: 0.8025
# Epoch 83: accuracy did not improve from 0.78125
# 3/3 [==============================] - 12s 4s/step - loss: 0.6537 - accuracy: 0.7500 - precision: 0.8025 - val_loss: 1.2839 - val_accuracy: 0.5312 - val_precision: 0.6418
# Epoch 84/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8646 - accuracy: 0.6979 - precision: 0.7500
# Epoch 84: accuracy did not improve from 0.78125
# 3/3 [==============================] - 11s 4s/step - loss: 0.8646 - accuracy: 0.6979 - precision: 0.7500 - val_loss: 0.8848 - val_accuracy: 0.6667 - val_precision: 0.7532
# Epoch 85/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8439 - accuracy: 0.6771 - precision: 0.7763
# Epoch 85: accuracy did not improve from 0.78125
# 3/3 [==============================] - 10s 3s/step - loss: 0.8439 - accuracy: 0.6771 - precision: 0.7763 - val_loss: 1.0286 - val_accuracy: 0.6875 - val_precision: 0.7375
# Epoch 86/100
# 3/3 [==============================] - ETA: 0s - loss: 0.6939 - accuracy: 0.7000 - precision: 0.7467
# Epoch 86: accuracy did not improve from 0.78125
# 3/3 [==============================] - 10s 3s/step - loss: 0.6939 - accuracy: 0.7000 - precision: 0.7467 - val_loss: 0.9663 - val_accuracy: 0.6979 - val_precision: 0.7692
# Epoch 87/100
# 3/3 [==============================] - ETA: 0s - loss: 0.6553 - accuracy: 0.7708 - precision: 0.8235
# Epoch 87: accuracy did not improve from 0.78125
# 3/3 [==============================] - 10s 4s/step - loss: 0.6553 - accuracy: 0.7708 - precision: 0.8235 - val_loss: 1.5080 - val_accuracy: 0.5521 - val_precision: 0.6133
# Epoch 88/100
# 3/3 [==============================] - ETA: 0s - loss: 0.5214 - accuracy: 0.8333 - precision: 0.8876
# Epoch 88: accuracy improved from 0.78125 to 0.83333, saving model to ALEXNET.h5
# 3/3 [==============================] - 13s 5s/step - loss: 0.5214 - accuracy: 0.8333 - precision: 0.8876 - val_loss: 2.1359 - val_accuracy: 0.5104 - val_precision: 0.5679
# Epoch 89/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8415 - accuracy: 0.7292 - precision: 0.7473
# Epoch 89: accuracy did not improve from 0.83333
# 3/3 [==============================] - 11s 4s/step - loss: 0.8415 - accuracy: 0.7292 - precision: 0.7473 - val_loss: 1.4037 - val_accuracy: 0.5521 - val_precision: 0.6571
# Epoch 90/100
# 3/3 [==============================] - ETA: 0s - loss: 0.7868 - accuracy: 0.7188 - precision: 0.7528
# Epoch 90: accuracy did not improve from 0.83333
# 3/3 [==============================] - 11s 4s/step - loss: 0.7868 - accuracy: 0.7188 - precision: 0.7528 - val_loss: 0.8945 - val_accuracy: 0.6979 - val_precision: 0.7895
# Epoch 91/100
# 3/3 [==============================] - ETA: 0s - loss: 0.6953 - accuracy: 0.7812 - precision: 0.8161
# Epoch 91: accuracy did not improve from 0.83333
# 3/3 [==============================] - 10s 4s/step - loss: 0.6953 - accuracy: 0.7812 - precision: 0.8161 - val_loss: 0.8477 - val_accuracy: 0.6771 - val_precision: 0.7407
# Epoch 92/100
# 3/3 [==============================] - ETA: 0s - loss: 0.6352 - accuracy: 0.6875 - precision: 0.7875
# Epoch 92: accuracy did not improve from 0.83333
# 3/3 [==============================] - 11s 4s/step - loss: 0.6352 - accuracy: 0.6875 - precision: 0.7875 - val_loss: 0.7817 - val_accuracy: 0.7188 - val_precision: 0.7654
# Epoch 93/100
# 3/3 [==============================] - ETA: 0s - loss: 0.5212 - accuracy: 0.8542 - precision: 0.8706
# Epoch 93: accuracy improved from 0.83333 to 0.85417, saving model to ALEXNET.h5
# 3/3 [==============================] - 22s 10s/step - loss: 0.5212 - accuracy: 0.8542 - precision: 0.8706 - val_loss: 0.7267 - val_accuracy: 0.7604 - val_precision: 0.7711
# Epoch 94/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8928 - accuracy: 0.6979 - precision: 0.7444
# Epoch 94: accuracy did not improve from 0.85417
# 3/3 [==============================] - 10s 4s/step - loss: 0.8928 - accuracy: 0.6979 - precision: 0.7444 - val_loss: 1.5728 - val_accuracy: 0.5938 - val_precision: 0.6471
# Epoch 95/100
# 3/3 [==============================] - ETA: 0s - loss: 0.5147 - accuracy: 0.7917 - precision: 0.8506
# Epoch 95: accuracy did not improve from 0.85417
# 3/3 [==============================] - 11s 4s/step - loss: 0.5147 - accuracy: 0.7917 - precision: 0.8506 - val_loss: 1.2943 - val_accuracy: 0.6771 - val_precision: 0.7241
# Epoch 96/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8501 - accuracy: 0.7396 - precision: 0.7363
# Epoch 96: accuracy did not improve from 0.85417
# 3/3 [==============================] - 10s 4s/step - loss: 0.8501 - accuracy: 0.7396 - precision: 0.7363 - val_loss: 0.7206 - val_accuracy: 0.7708 - val_precision: 0.7865
# Epoch 97/100
# 3/3 [==============================] - ETA: 0s - loss: 0.5985 - accuracy: 0.7500 - precision: 0.7907
# Epoch 97: accuracy did not improve from 0.85417
# 3/3 [==============================] - 11s 4s/step - loss: 0.5985 - accuracy: 0.7500 - precision: 0.7907 - val_loss: 0.7782 - val_accuracy: 0.7396 - val_precision: 0.7816
# Epoch 98/100
# 3/3 [==============================] - ETA: 0s - loss: 0.4636 - accuracy: 0.8542 - precision: 0.8837
# Epoch 98: accuracy did not improve from 0.85417
# 3/3 [==============================] - 11s 4s/step - loss: 0.4636 - accuracy: 0.8542 - precision: 0.8837 - val_loss: 1.4104 - val_accuracy: 0.6146 - val_precision: 0.6512
# Epoch 99/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8844 - accuracy: 0.7083 - precision: 0.7386
# Epoch 99: accuracy did not improve from 0.85417
# 3/3 [==============================] - 10s 4s/step - loss: 0.8844 - accuracy: 0.7083 - precision: 0.7386 - val_loss: 0.8871 - val_accuracy: 0.6875 - val_precision: 0.7412
# Epoch 100/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9588 - accuracy: 0.6771 - precision: 0.7191
# Epoch 100: accuracy did not improve from 0.85417
# 3/3 [==============================] - 11s 4s/step - loss: 0.9588 - accuracy: 0.6771 - precision: 0.7191 - val_loss: 1.0634 - val_accuracy: 0.6875 - val_precision: 0.7294
# Epoch 50/50
# 3/3 [==============================] - ETA: 0s - loss: 1.3293 - accuracy: 0.5104 - precision: 0.6250
# Epoch 50: accuracy did not improve from 0.54167
# 3/3 [==============================] - 8s 3s/step - loss: 1.3293 - accuracy: 0.5104 - precision: 0.6250 - val_loss: 1.9865 - val_accuracy: 0.2812 - val_precision: 0.3488

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'val_loss', 'val_accuracy', 'val_precision'])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 8))
plt.plot(history.history['accuracy'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['accuracy'][i]*100,2),xy=(i,history.history['accuracy'][i]))

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(history.history['loss'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['loss'][i]*100,2),xy=(i,history.history['loss'][i]))

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()
